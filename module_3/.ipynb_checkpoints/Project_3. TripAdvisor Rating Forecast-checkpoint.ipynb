# %% [markdown]
# # Description of variables

# %% [markdown]
# The initial version of dataset consists of 10 columns containing the following information:
#
# * Restaurant_id — id of a restaurant / restaurant chain;
#
#
# * City — restaurant's location (city);
#
#
# * Cuisine Style — cuisine which a dish can be related to;
#
#
# * Ranking — restaurant's place in the ranking of all the cities' restaurants;
#
#
# * Rating — the rating of a restaurant according to TripAdvisor **(this is the target variable)**;
#
#
# * Price Range — the price range of the restaurant;
#
#
# * Number of Reviews — number of reviews for a restaurant on TripAdvisor;
#
#
# * Reviews — info about two first reviews that are displayed on TripAdvisor;
#
#
# * URL_TA — URL of restaurant's web-page on TripAdvosor;
#
#
# * ID_TA — restaurant's id in TripAdvisor's Database.

# %% [markdown]
# # Import of modules

# %%
import pandas as pd
import numpy as np
import scipy
import matplotlib.pyplot as plt
import statsmodels.api as sm
import scipy.stats as stats
import seaborn as sns
import missingno as msno
import os
import ast
import warnings
import re
import urllib.request
import requests
import random
from bs4 import BeautifulSoup as BS
from itertools import combinations
from collections import Counter

from sklearn.model_selection import train_test_split  # A tool for splitting a dataset into training and testing samples
from sklearn.ensemble import RandomForestRegressor  # A tool for building a model
from sklearn import metrics  # Tools for model's accuracy measurement

from sklearn.preprocessing import MinMaxScaler, PolynomialFeatures, MultiLabelBinarizer

# %matplotlib inline
sns.set(style='whitegrid')
warnings.simplefilter('ignore')

# %%
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/living-standards/living_standards.txt
# /kaggle/input/sf-dst-restaurant-rating/sample_submission.csv
# /kaggle/input/sf-dst-restaurant-rating/kaggle_task.csv
# /kaggle/input/sf-dst-restaurant-rating/main_task.csv
# /kaggle/input/tourism/tourism.txt

# %% [markdown]
# Fixing Random seed and package version for reproducible experiments:

# %%
RANDOM_SEED = 42

# %%
# !pip freeze > requirements.txt

# %%
DATA_DIR = '/kaggle/input/sf-dst-restaurant-rating/'
df_train = pd.read_csv(DATA_DIR+'/main_task.csv')
df_test = pd.read_csv(DATA_DIR+'kaggle_task.csv')
sample_submission = pd.read_csv(DATA_DIR+'/sample_submission.csv')

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Restaurant_id      10000 non-null  object
#  1   City               10000 non-null  object
#  2   Cuisine Style      7693 non-null   object
#  3   Ranking            10000 non-null  float64
#  4   Price Range        6525 non-null   object
#  5   Number of Reviews  9343 non-null   float64
#  6   Reviews            9998 non-null   object
#  7   URL_TA             10000 non-null  object
#  8   ID_TA              10000 non-null  object
# dtypes: float64(2), object(7)
# memory usage: 703.2+ KB

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Restaurant_id      40000 non-null  object
#  1   City               40000 non-null  object
#  2   Cuisine Style      30717 non-null  object
#  3   Ranking            40000 non-null  float64
#  4   Rating             40000 non-null  float64
#  5   Price Range        26114 non-null  object
#  6   Number of Reviews  37457 non-null  float64
#  7   Reviews            40000 non-null  object
#  8   URL_TA             40000 non-null  object
#  9   ID_TA              40000 non-null  object
# dtypes: float64(3), object(7)
# memory usage: 3.1+ MB

# %%
df_train['sample'] = 1  # Train data
df_test['sample'] = 0  # Test data
df_test['Rating'] = 0  # Filling with zeros since there is no data there (needs to be predicted)

data = df_test.append(df_train, sort=False).reset_index(drop=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Restaurant_id      50000 non-null  object
#  1   City               50000 non-null  object
#  2   Cuisine Style      38410 non-null  object
#  3   Ranking            50000 non-null  float64
#  4   Price Range        32639 non-null  object
#  5   Number of Reviews  46800 non-null  float64
#  6   Reviews            49998 non-null  object
#  7   URL_TA             50000 non-null  object
#  8   ID_TA              50000 non-null  object
#  9   sample             50000 non-null  int64
#  10  Rating             50000 non-null  float64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 4.2+ MB

# %% [markdown]
# # Data preprocessing

# %% [markdown]
# Lets get some basic info about the dataset:

# %%
data.sample(5)
# Out:
#       Restaurant_id    City  \
# 22856       id_6380   Paris
# 36940       id_1021  Vienna
# 12532       id_1963  Warsaw
# 30547        id_888   Milan
# 6102        id_6102   Paris
#
#                                            Cuisine Style  Ranking Price Range  \
# 22856  ['Moroccan', 'French', 'European', 'Middle Eas...   6381.0    $$ - $$$
# 36940                                                NaN   1022.0         NaN
# 12532   ['Brew Pub', 'Polish', 'Bar', 'European', 'Pub']   1965.0           $
# 30547  ['Pizza', 'Vegetarian Friendly', 'Vegan Options']    890.0           $
# 6102                                        ['American']   2293.0           $
#
#        Number of Reviews                                            Reviews  \
# 22856               59.0  [['Friendly and affordable', 'Strictly neighbo...
# 36940               15.0                                           [[], []]
# 12532                NaN                                           [[], []]
# 30547               33.0  [['Best ingredients best pizza best taste', 'A...
# 6102                42.0  [['Such a cool place!', 'A great find'], ['01/...
#
#                                                   URL_TA      ID_TA  sample  \
# 22856  /Restaurant_Review-g187147-d6451025-Reviews-Au...   d6451025       1
# 36940  /Restaurant_Review-g190454-d8368436-Reviews-Ca...   d8368436       1
# 12532  /Restaurant_Review-g274856-d11712376-Reviews-P...  d11712376       1
# 30547  /Restaurant_Review-g187849-d12631954-Reviews-B...  d12631954       1
# 6102   /Restaurant_Review-g187147-d10494505-Reviews-R...  d10494505       0
#
#        Rating
# 22856     4.0
# 36940     4.5
# 12532     3.0
# 30547     4.5
# 6102      0.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Restaurant_id      50000 non-null  object
#  1   City               50000 non-null  object
#  2   Cuisine Style      38410 non-null  object
#  3   Ranking            50000 non-null  float64
#  4   Price Range        32639 non-null  object
#  5   Number of Reviews  46800 non-null  float64
#  6   Reviews            49998 non-null  object
#  7   URL_TA             50000 non-null  object
#  8   ID_TA              50000 non-null  object
#  9   sample             50000 non-null  int64
#  10  Rating             50000 non-null  float64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 4.2+ MB

# %%
msno.matrix(data)

# %% [markdown]
# **Are the any duplicated rows in the dataset?**

# %%
print('Fortunately, no duplicates exist' if data.duplicated().sum() == 0 else 'Yes, there are')
# Out:
# Fortunately, no duplicates exist

# %% [markdown]
# Descriptive statistics:

# %%
data.describe()
# Out:
#             Ranking  Number of Reviews        sample        Rating
# count  50000.000000       46800.000000  50000.000000  50000.000000
# mean    3664.427520         124.471197      0.800000      3.194430
# std     3700.092452         294.114345      0.400004      1.705453
# min        1.000000           2.000000      0.000000      0.000000
# 25%      972.000000           9.000000      1.000000      3.000000
# 50%     2278.000000          33.000000      1.000000      4.000000
# 75%     5241.000000         115.000000      1.000000      4.500000
# max    16444.000000        9660.000000      1.000000      5.000000

# %% [markdown]
# **So at first sight the following columns have no missing values:**
#
# * Restaurant_id
#
# * Cuisine Style
#
# * City
#
# * Ranking
#
# * Rating
#
# * Reviews
#
# * URL_TA

# %% [markdown]
# Columns have the following types:

# %%
for column in data.columns:
    print(f'dtype of {column} column is {type(data[column].iloc[0])}')
# Out:
# dtype of Restaurant_id column is <class 'str'>
# dtype of City column is <class 'str'>
# dtype of Cuisine Style column is <class 'str'>
# dtype of Ranking column is <class 'numpy.float64'>
# dtype of Price Range column is <class 'str'>
# dtype of Number of Reviews column is <class 'numpy.float64'>
# dtype of Reviews column is <class 'str'>
# dtype of URL_TA column is <class 'str'>
# dtype of ID_TA column is <class 'str'>
# dtype of sample column is <class 'numpy.int64'>
# dtype of Rating column is <class 'numpy.float64'>

# %%
df = data.copy(deep=True)
df.columns = ['rest_id', 'city', 'cuisine', 'ranking',
                'price_range', 'reviews_amount', 'reviews', 'url_ta',
                'id_ta', 'sample', 'rating']

# %%
df.head(2)
# Out:
#   rest_id      city                                            cuisine  \
# 0    id_0     Paris                                     ['Bar', 'Pub']
# 1    id_1  Helsinki  ['European', 'Scandinavian', 'Gluten Free Opti...
#
#    ranking price_range  reviews_amount  \
# 0  12963.0    $$ - $$$             4.0
# 1    106.0    $$ - $$$            97.0
#
#                                              reviews  \
# 0                                           [[], []]
# 1  [['Very good reviews!', 'Fine dining in Hakani...
#
#                                               url_ta      id_ta  sample  \
# 0  /Restaurant_Review-g187147-d10746918-Reviews-L...  d10746918       0
# 1  /Restaurant_Review-g189934-d6674944-Reviews-Ra...   d6674944       0
#
#    rating
# 0     0.0
# 1     0.0

# %% [markdown]
# Let's build basic functions to display information:

# %%
def show_unique(column):
    print(f"Number of unique values for '{column}' column: {df[column].nunique()}")
    print(f"\nUnique values in '{column}' column:\n {df[column].unique()}")

# %%
def missing(column):
    print(f"Number of missing values for column '{column}': {df[column].isna().sum()}")

# %% [markdown]
# **Next I will check each variable apart for some missing values, outliers or just incorrect information.**

# %% [markdown]
# ## Restaurant ID
#
# This value is unlikely to be informative but nevertheless, I will preprocess it as well for some reason.

# %%
show_unique('rest_id')
# Out:
# Number of unique values for 'rest_id' column: 13094
#
# Unique values in 'rest_id' column:
#  ['id_0' 'id_1' 'id_2' ... 'id_15736' 'id_12774' 'id_11658']

# %%
missing('rest_id')
# Out:
# Number of missing values for column 'rest_id': 0

# %% [markdown]
# There are to many unique ID numbers to check them all. So I will save myself from future headache by choosing only values which match a special regex pattern:

# %%
def id_check(cell):
    import re
    ptrn = re.compile(r'id_\d+')
    result = re.search(ptrn, cell)
    
    return result.group(0)

# %%
df.rest_id = df.rest_id.apply(id_check)

# %% [markdown]
# Let's look at values now:

# %%
show_unique('rest_id')
# Out:
# Number of unique values for 'rest_id' column: 13094
#
# Unique values in 'rest_id' column:
#  ['id_0' 'id_1' 'id_2' ... 'id_15736' 'id_12774' 'id_11658']

# %% [markdown]
# Actually, we can see that nothing changed but, at least, there is some confidence now that everything is OK with this column.
#
# Now we can drop this column as it plays no role in the future ML model:

# %%
df.drop(['rest_id'], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   city            50000 non-null  object
#  1   cuisine         38410 non-null  object
#  2   ranking         50000 non-null  float64
#  3   price_range     32639 non-null  object
#  4   reviews_amount  46800 non-null  float64
#  5   reviews         49998 non-null  object
#  6   url_ta          50000 non-null  object
#  7   id_ta           50000 non-null  object
#  8   sample          50000 non-null  int64
#  9   rating          50000 non-null  float64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 3.8+ MB

# %% [markdown]
# ## City

# %%
show_unique('city')
# Out:
# Number of unique values for 'city' column: 31
#
# Unique values in 'city' column:
#  ['Paris' 'Helsinki' 'Edinburgh' 'London' 'Bratislava' 'Lisbon' 'Budapest'
#  'Stockholm' 'Rome' 'Milan' 'Munich' 'Hamburg' 'Prague' 'Vienna' 'Dublin'
#  'Barcelona' 'Brussels' 'Madrid' 'Oslo' 'Amsterdam' 'Berlin' 'Lyon'
#  'Athens' 'Warsaw' 'Oporto' 'Krakow' 'Copenhagen' 'Luxembourg' 'Zurich'
#  'Geneva' 'Ljubljana']

# %%
missing('city')
# Out:
# Number of missing values for column 'city': 0

# %% [markdown]
# Top-10 cities by number of restaurants:

# %%
fig, ax = plt.subplots(figsize=(14, 7))
df.city.value_counts()[:10].plot(kind='bar')

plt.xticks(size=15, rotation=45)
plt.yticks(size=15)

ax.set_title('Top ten cities by number of restaurants', size=20)
ax.set_xlabel('Cities', size=20)
ax.set_ylabel('Number of restaurants', size=20)
# Out:
# Text(0, 0.5, 'Number of restaurants')

# %% [markdown]
# * London and Paris cover the majority of restaurants

# %% [markdown]
# ## Cuisine

# %%
show_unique('cuisine')
# Out:
# Number of unique values for 'cuisine' column: 10731
#
# Unique values in 'cuisine' column:
#  ["['Bar', 'Pub']"
#  "['European', 'Scandinavian', 'Gluten Free Options', 'Vegetarian Friendly', 'Vegan Options']"
#  "['Vegetarian Friendly']" ...
#  "['Steakhouse', 'Barbecue', 'Australian', 'Argentinean', 'South American']"
#  "['French', 'American', 'Cafe', 'Healthy', 'Soups']"
#  "['French', 'Contemporary', 'Fusion', 'Gastropub']"]

# %%
missing('cuisine')
# Out:
# Number of missing values for column 'cuisine': 11590

# %% [markdown]
# It would probably be informative to know how many different types of cuisine there are in dataset.

# %%
counter = Counter()
cuisine_df = data['Cuisine Style'].dropna().apply(ast.literal_eval)

for cuisines in cuisine_df:
    for cuisine in cuisines:
        counter[cuisine] += 1
        
print(f'{len(counter.keys())} different cuisines')
# Out:
# 125 different cuisines

# %% [markdown]
# Which of cuisines is the most frequent?

# %%
print(f'{counter.most_common()[0][0]} - the most popular cuisine style')
# Out:
# Vegetarian Friendly - the most popular cuisine style

# %% [markdown]
# Mean amount of cuisines for each restaurant?

# %%
cuisine = data['Cuisine Style'].apply(lambda x: ast.literal_eval(x) if not pd.isna(x) else '1')
print(f'Mean amount of cuisines: {round(cuisine.apply(lambda x: len(x)).mean(), 2)}')
# Out:
# Mean amount of cuisines: 2.63

# %%
df_cuisine = df[['cuisine', 'city']]
df_cuisine
# Out:
#                                                  cuisine        city
# 0                                         ['Bar', 'Pub']       Paris
# 1      ['European', 'Scandinavian', 'Gluten Free Opti...    Helsinki
# 2                                ['Vegetarian Friendly']   Edinburgh
# 3      ['Italian', 'Mediterranean', 'European', 'Vege...      London
# 4      ['Italian', 'Mediterranean', 'European', 'Seaf...  Bratislava
# ...                                                  ...         ...
# 49995  ['Italian', 'Vegetarian Friendly', 'Vegan Opti...       Milan
# 49996  ['French', 'American', 'Bar', 'European', 'Veg...       Paris
# 49997                              ['Japanese', 'Sushi']   Stockholm
# 49998  ['Polish', 'European', 'Eastern European', 'Ce...      Warsaw
# 49999                                        ['Spanish']       Milan
#
# [50000 rows x 2 columns]

# %% [markdown]
# If you use several links to check web-pages of restaurants which don't have any info about **cuisine**, you will make sure that usually this info doesn't actually exist even on TripAdvisor:

# %%
df[df.cuisine.isna()].url_ta.unique()[:10]
# Out:
# array(['/Restaurant_Review-g274887-d8286886-Reviews-Beer_N_Scooter-Budapest_Central_Hungary.html',
#        '/Restaurant_Review-g187791-d7818546-Reviews-Jerry_Thomas_Speakeasy-Rome_Lazio.html',
#        '/Restaurant_Review-g187331-d1344523-Reviews-Il_Cammino-Hamburg.html',
#        '/Restaurant_Review-g190454-d8435085-Reviews-Angkor_Club-Vienna.html',
#        '/Restaurant_Review-g187497-d8334752-Reviews-Restaurante_Laumon-Barcelona_Catalonia.html',
#        '/Restaurant_Review-g187514-d13202032-Reviews-Wan-Madrid.html',
#        '/Restaurant_Review-g187497-d5795143-Reviews-La_Bona_Taula_de_Llica-Barcelona_Catalonia.html',
#        '/Restaurant_Review-g187147-d11953078-Reviews-Bistrot_Wattignies-Paris_Ile_de_France.html',
#        '/Restaurant_Review-g186338-d13234520-Reviews-The_Granary_Brasserie-London_England.html',
#        '/Restaurant_Review-g190479-d12170920-Reviews-Kaffegutta-Oslo_Eastern_Norway.html'],
#       dtype=object)

# %% [markdown]
# Filling these missing values with an empty list for now :

# %%
cuisine = df.cuisine
df.cuisine.fillna('[]', inplace=True)

# %% [markdown]
# When dealing with these NaN-values it makes sense to pay attention to the city where the restaurant is located. Probably, this info will allow to fill those values approximately.

# %% [markdown]
# Now let's get **the most common cuisine** for each city:

# %%
df_cuisine.groupby(['city']).cuisine.value_counts()
# Out:
# city       cuisine
# Amsterdam  ['Dutch', 'European']                                                                                 33
#            ['Asian', 'Indonesian']                                                                               15
#            ['Italian']                                                                                           14
#            ['International']                                                                                     13
#            ['Italian', 'Pizza', 'European', 'Vegetarian Friendly']                                               13
#                                                                                                                  ..
# Zurich     ['Swiss', 'Seafood', 'European', 'Central European', 'Vegetarian Friendly', 'Gluten Free Options']     1
#            ['Swiss']                                                                                              1
#            ['Turkish', 'Middle Eastern', 'Fast Food', 'Halal']                                                    1
#            ['Turkish']                                                                                            1
#            ['Vietnamese', 'Asian', 'Soups']                                                                       1
# Name: cuisine, Length: 16490, dtype: int64

# %%
new_cuisine = df_cuisine.groupby(['city']).agg(lambda x: x.value_counts().index[0])
new_cuisine.head()
# Out:
#                           cuisine
# city
# Amsterdam   ['Dutch', 'European']
# Athens                  ['Greek']
# Barcelona             ['Spanish']
# Berlin                ['Italian']
# Bratislava                ['Pub']

# %%
def fill_cuisine(row):
    '''
    This function substitutes the missing value
    with the most common value for a certain city
    '''
    if pd.isna(row['cuisine']):
        row['cuisine'] = new_cuisine.loc[row['city']].iloc[0]

    return row

# %%
df = df.apply(fill_cuisine, axis=1)
df.head(2)
# Out:
#        city                                            cuisine  ranking  \
# 0     Paris                                     ['Bar', 'Pub']  12963.0
# 1  Helsinki  ['European', 'Scandinavian', 'Gluten Free Opti...    106.0
#
#   price_range  reviews_amount  \
# 0    $$ - $$$             4.0
# 1    $$ - $$$            97.0
#
#                                              reviews  \
# 0                                           [[], []]
# 1  [['Very good reviews!', 'Fine dining in Hakani...
#
#                                               url_ta      id_ta  sample  \
# 0  /Restaurant_Review-g187147-d10746918-Reviews-L...  d10746918       0
# 1  /Restaurant_Review-g189934-d6674944-Reviews-Ra...   d6674944       0
#
#    rating
# 0     0.0
# 1     0.0

# %%
print(f'Number of missing values for "cuisine" column: {df.cuisine.isna().sum()}')
# Out:
# Number of missing values for "cuisine" column: 0

# %% [markdown]
# So we filled the values of 'cuisine' column with the most frequent value for each city.
#
# Later it will be more obvious whether this helped to **enhance the model quality or not**.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   city            50000 non-null  object
#  1   cuisine         50000 non-null  object
#  2   ranking         50000 non-null  float64
#  3   price_range     32639 non-null  object
#  4   reviews_amount  46800 non-null  float64
#  5   reviews         49998 non-null  object
#  6   url_ta          50000 non-null  object
#  7   id_ta           50000 non-null  object
#  8   sample          50000 non-null  int64
#  9   rating          50000 non-null  float64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 3.8+ MB

# %% [markdown]
# ## Ranking

# %%
show_unique('ranking')
# Out:
# Number of unique values for 'ranking' column: 12975
#
# Unique values in 'ranking' column:
#  [12963.   106.   810. ... 15748.  8896.  6058.]

# %%
missing('ranking')
# Out:
# Number of missing values for column 'ranking': 0

# %% [markdown]
# Everything is nice with this variable despite the fact that it should be of **int type** rather than float type:

# %%
df.ranking = df.ranking.astype('int')

# %%
df.sample(5)
# Out:
#          city                                            cuisine  ranking  \
# 32956  London  ['Indian', 'Asian', 'Vegetarian Friendly', 'Ve...     1131
# 33324   Paris           ['Asian', 'Thai', 'Vegetarian Friendly']     4145
# 880    Madrid                                                 []     7023
# 2594   London                                                 []    11910
# 9501   Zurich  ['Italian', 'Fast Food', 'Mediterranean', 'Eur...      682
#
#       price_range  reviews_amount  \
# 32956    $$ - $$$           300.0
# 33324    $$ - $$$           206.0
# 880           NaN             8.0
# 2594          NaN             5.0
# 9501            $            93.0
#
#                                                  reviews  \
# 32956  [['Cozy restaurant, great food', 'Very reasona...
# 33324  [['Lovely place - good food and service', 'Ver...
# 880                                             [[], []]
# 2594   [['Very average', 'I do love it!'], ['07/05/20...
# 9501   [['Great value for money !', 'Good pasta, fast...
#
#                                                   url_ta      id_ta  sample  \
# 32956  /Restaurant_Review-g186338-d2456325-Reviews-Pa...   d2456325       1
# 33324  /Restaurant_Review-g187147-d850113-Reviews-Mai...    d850113       1
# 880    /Restaurant_Review-g187514-d7818372-Reviews-Al...   d7818372       0
# 2594   /Restaurant_Review-g186338-d11873684-Reviews-B...  d11873684       0
# 9501   /Restaurant_Review-g188113-d1964852-Reviews-Ts...   d1964852       0
#
#        rating
# 32956     4.0
# 33324     4.0
# 880       0.0
# 2594      0.0
# 9501      0.0

# %% [markdown]
# Let's check this variable for some strange values (maybe outliers) by cities:

# %%
for city in df.city.unique():
    fig = plt.figure(figsize=(18, 5))
    ax_1 = plt.subplot(1, 2, 1)
    sns.boxplot(df[df['city'] == city]['ranking'])
    ax_1.set_title(f'Boxplot for {city} restaurants ranking', size=15)
    
    ax_2 = plt.subplot(1, 2, 2)
    sns.distplot(df[df['city'] == city]['ranking'])
    ax_2.set_title(f'Distribution plot for {city} restaurants ranking', size=15)

# %% [markdown]
# * The distribution of ranking differs depending on cities
#
# * Sometimes it is normal, sometimes binomial, sometimes just assymetrical

# %%
print(f'Number of zero ranks: {(df.ranking == 0).sum()}')
# Out:
# Number of zero ranks: 0

# %% [markdown]
# So, these are ranks and they seem to be quite adequate.

# %% [markdown]
# ## Rating (!)

# %%
show_unique('rating')
# Out:
# Number of unique values for 'rating' column: 10
#
# Unique values in 'rating' column:
#  [0.  3.5 4.  4.5 5.  3.  2.5 2.  1.  1.5]

# %%
missing('rating')
# Out:
# Number of missing values for column 'rating': 0

# %% [markdown]
# Defining a function to display boxplot and distplot for numerical values:

# %%
def dist_box(series):
    fig = plt.figure(figsize=(18, 5))
    ax_1 = plt.subplot(1, 2, 1)
    ax_2 = sns.distplot(series, bins=10)
    plt.yticks(size=15)
    plt.xticks(size=15)
    ax_1.set_ylabel('Frequency', size=13)
    ax_1.set_xlabel(f'{series.name}', size=13)
    ax_1.set_title(f'{series.name} distribution', size=13)

    ax_2 = plt.subplot(1, 2, 2)
    ax_2 = sns.boxplot(series)
    plt.yticks(size=15)
    plt.xticks(size=15)
    ax_2.set_xlabel(f'{series.name}', size=13)
    ax_2.set_title(f'{series.name} boxplot', size=13)

# %%
dist_box(df[df.rating > 0]['rating'])

# %% [markdown]
# It is noticable that **rating has approximately normal distribution** provided that there are no values less than **3.0**.
#
# Let's check the normality of its distribution using QQ-Plot:

# %%
sm.qqplot(df[df.rating > 2.5].rating, stats.norm, fit=True, line='45')
plt.show()

# %%
print(f'There are {df[(df.rating < 2.5) & (df.rating != 0)].rating.count()} <outliers> in "rating" column')
# Out:
# There are 806 <outliers> in "rating" column

# %%
# fig, ax = plt.subplots(figsize=(14, 6))
# new_df[new_df.rating > 0].rating.plot(kind='hist', bins=6)

# %% [markdown]
# * After deleting the values less than **2.5** we got a distribution of the **target variable** close to normal

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   city            50000 non-null  object
#  1   cuisine         50000 non-null  object
#  2   ranking         50000 non-null  int64
#  3   price_range     32639 non-null  object
#  4   reviews_amount  46800 non-null  float64
#  5   reviews         49998 non-null  object
#  6   url_ta          50000 non-null  object
#  7   id_ta           50000 non-null  object
#  8   sample          50000 non-null  int64
#  9   rating          50000 non-null  float64
# dtypes: float64(2), int64(2), object(6)
# memory usage: 3.8+ MB

# %% [markdown]
# Despite the fact that according to IQR values **1** and **1.5** are considered as outliers they are actually not. If we go to [TripAdvisor](https://www.tripadvisor.com/), we can get convinced that these values can be observed, probably, they are just rare.

# %% [markdown]
# ## Price range

# %%
show_unique('price_range')
# Out:
# Number of unique values for 'price_range' column: 3
#
# Unique values in 'price_range' column:
#  ['$$ - $$$' '$$$$' '$' nan]

# %%
missing('price_range')
# Out:
# Number of missing values for column 'price_range': 17361

# %% [markdown]
# It is better to create some comprehensible categories like this:

# %%
df.price_range = df.price_range.map({'$': 'low', '$$ - $$$': 'medium', '$$$$': 'high', np.nan: 'no price'})
df.sample(3)
# Out:
#          city                                        cuisine  ranking  \
# 15235  Lisbon                                             []     1928
# 13846  London                           ['Chinese', 'Asian']     6935
# 19184   Paris  ['French', 'European', 'Vegetarian Friendly']     4753
#
#       price_range  reviews_amount  \
# 15235    no price            15.0
# 13846      medium            65.0
# 19184      medium            63.0
#
#                                                  reviews  \
# 15235  [['Portuguese charisma coffee/bar', 'Músic and...
# 13846  [['A visit with friends', 'Always good 👌🏻'], [...
# 19184  [['Very good for a light lunch', 'Lovely terra...
#
#                                                   url_ta     id_ta  sample  \
# 15235  /Restaurant_Review-g189158-d697218-Reviews-Bic...   d697218       1
# 13846  /Restaurant_Review-g186338-d4261065-Reviews-Ta...  d4261065       1
# 19184  /Restaurant_Review-g187147-d7695606-Reviews-La...  d7695606       1
#
#        rating
# 15235     4.5
# 13846     4.0
# 19184     4.0

# %%
fig, ax = plt.subplots(figsize=(14, 6))
sns.countplot(df.price_range)

# %% [markdown]
# * The majority of restaurants have medium price level

# %% [markdown]
# So, probably, the more expensive the restaurant is, the more reviews it has. Let's check amount of reviews for normal distribution:

# %%
dist_box(df.reviews_amount)

# %%
print(f'Amount of reviews > 2000: {df[df.reviews_amount > 2000].reviews_amount.count()} observations')
# Out:
# Amount of reviews > 2000: 171 observations

# %% [markdown]
# So this is not even close to normal distribution. That is why it is better to use **Mann-Whitney rank** test rather than Student's t-test since it is quite robust to the type if distribution.
#
# * The **null hypothesis (H0)** is that there are no significant differences between these groups;
#
# * The **alternative (Ha)** is that there are significant differences.

# %%
for pair in combinations(sorted(df.price_range.dropna().unique()), 2):
    p_value = scipy.stats.mannwhitneyu(df[df.price_range == pair[0]].reviews_amount,
                                       df[df.price_range == pair[1]].reviews_amount).pvalue / 3
    if p_value < 0.05:
        print(f'Significant differences were found between groups {pair}')
# Out:
# Significant differences were found between groups ('high', 'low')
# Significant differences were found between groups ('high', 'medium')
# Significant differences were found between groups ('high', 'no price')
# Significant differences were found between groups ('low', 'medium')
# Significant differences were found between groups ('low', 'no price')
# Significant differences were found between groups ('medium', 'no price')

# %% [markdown]
# The ratio itself remains quite similar to the one before filling missing values:

# %%
fig, ax = plt.subplots(figsize=(14, 6))
sns.countplot(df.price_range)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   city            50000 non-null  object
#  1   cuisine         50000 non-null  object
#  2   ranking         50000 non-null  int64
#  3   price_range     50000 non-null  object
#  4   reviews_amount  46800 non-null  float64
#  5   reviews         49998 non-null  object
#  6   url_ta          50000 non-null  object
#  7   id_ta           50000 non-null  object
#  8   sample          50000 non-null  int64
#  9   rating          50000 non-null  float64
# dtypes: float64(2), int64(2), object(6)
# memory usage: 3.8+ MB

# %% [markdown]
# ## Amount of reviews

# %%
show_unique('reviews_amount')
# Out:
# Number of unique values for 'reviews_amount' column: 1573
#
# Unique values in 'reviews_amount' column:
#  [   4.   97.   28. ...  765. 2272. 2297.]

# %%
missing('reviews_amount')
# Out:
# Number of missing values for column 'reviews_amount': 3200

# %% [markdown]
# The distribution of this variable is not even close to normal and there are outliers according to IQR. But these values actually exist, so there is no reason do delete them yet.

# %%
dist_box(df[df.reviews_amount < 3000].reviews_amount)

# %% [markdown]
# If you check out the following web-pages of restaurants with zero reviews you can see that **at this moment** there are actually no  reviews (or there are **a few**) and there is no information about **price range**. Since this dataset is not absolutely up-to-date, it makes sense to substitute NaN-values with **zero**:

# %%
df[df.reviews_amount.isna()].url_ta.unique()
# Out:
# array(['/Restaurant_Review-g274887-d8286886-Reviews-Beer_N_Scooter-Budapest_Central_Hungary.html',
#        '/Restaurant_Review-g187514-d13202032-Reviews-Wan-Madrid.html',
#        '/Restaurant_Review-g274707-d7124128-Reviews-Chocobamba-Prague_Bohemia.html',
#        ...,
#        '/Restaurant_Review-g187514-d12182212-Reviews-Cafeteria_Restaurante_El_Garrotin-Madrid.html',
#        '/Restaurant_Review-g187323-d7761701-Reviews-Aroshi-Berlin.html',
#        '/Restaurant_Review-g186338-d5550626-Reviews-The_Craft_Beer_Social_Club-London_England.html'],
#       dtype=object)

# %%
df.reviews_amount.fillna(value=0, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   city            50000 non-null  object
#  1   cuisine         50000 non-null  object
#  2   ranking         50000 non-null  int64
#  3   price_range     50000 non-null  object
#  4   reviews_amount  50000 non-null  float64
#  5   reviews         49998 non-null  object
#  6   url_ta          50000 non-null  object
#  7   id_ta           50000 non-null  object
#  8   sample          50000 non-null  int64
#  9   rating          50000 non-null  float64
# dtypes: float64(2), int64(2), object(6)
# memory usage: 3.8+ MB

# %% [markdown]
# ## Reviews

# %%
show_unique('reviews')
# Out:
# Number of unique values for 'reviews' column: 41857
#
# Unique values in 'reviews' column:
#  ['[[], []]'
#  "[['Very good reviews!', 'Fine dining in Hakaniemi'], ['12/05/2017', '10/29/2017']]"
#  "[['Better than the Links', 'Ivy Black'], ['12/28/2017', '12/06/2017']]"
#  ...
#  "[['Good by swedish standards', 'A hidden jewel in the middle of Västertorp...'], ['11/03/2016', '04/12/2008']]"
#  "[['Underground restaurant', 'Oldest Restaurant in Warsaw'], ['07/11/2017', '06/18/2017']]"
#  "[['Average', 'Nice an informal'], ['01/31/2016', '07/04/2012']]"]

# %%
missing('reviews')
# Out:
# Number of missing values for column 'reviews': 2

# %%
df.reviews.sample(15)
# Out:
# 9539     [['Wonderfull', 'Best charming cave in Paris']...
# 3114                                              [[], []]
# 37042    [['Good lunch spot for Japanese food'], ['12/2...
# 10487    [['For port wine lovers', 'Had to walk out'], ...
# 16930    [['Amazing food', 'Good Pasta to take home'], ...
# 22691    [['The most delicious food in Rome', 'Real foo...
# 15767    [['Very good food!', 'Great food, always'], ['...
# 18170                                             [[], []]
# 34182                                             [[], []]
# 13812    [['Hola senorita!', 'great coffee shop'], ['07...
# 6121     [['Possibly my new favorite in Brussels', 'Nic...
# 45886                          [['Nice!'], ['11/26/2016']]
# 18307    [['Excellent food and very good service'], ['0...
# 29389    [['Surprisingly amazing pub in Schaerbeek', 'B...
# 33666    [['Nice atmospheric burger place', 'Tasty burg...
# Name: reviews, dtype: object

# %% [markdown]
# If we check these two URLs where we have no info about reviews, we can see that there are actually some reviews on restaurants' web-pages:

# %%
df[df.reviews.isna()].url_ta.unique()
# Out:
# array(['/Restaurant_Review-g189158-d12683988-Reviews-O_Sitar-Lisbon_Lisbon_District_Central_Portugal.html',
#        '/Restaurant_Review-g190454-d12605368-Reviews-Rochus-Vienna.html'],
#       dtype=object)

# %% [markdown]
# It makes sense to create a new variable: **Dates of the latest reviews for each restaurant**.
#
# Defining a function to extract dates using a regular expression:

# %%
def get_dates(x):
    ptrn = r'\d{2}/\d{2}/\d{4}'
    result = re.findall(ptrn, x)
    
    if len(result) == 2:
        return [result[0], result[1]]
    elif len(result) == 1:
        return [result[0], np.nan]
    
    return [np.nan, np.nan]

# %% [markdown]
# Applying the function:

# %%
review_dates = pd.DataFrame(df.reviews.dropna().apply(get_dates).to_list(), 
                            columns=['latest_review_1', 'latest_review_2'])
review_dates = review_dates.apply(pd.to_datetime)
review_dates.sample(5)
# Out:
#       latest_review_1 latest_review_2
# 30677      2017-02-18      2017-11-07
# 45473      2017-11-01      2016-05-03
# 6500       2017-10-30      2017-09-07
# 46635      2017-10-24      2017-10-02
# 17439      2018-01-05      2017-12-31

# %%
df = pd.concat([df, review_dates], axis=1)
df.sample(10)
# Out:
#             city                                      cuisine  ranking  \
# 49123      Paris                                           []    10695
# 21164      Milan                            ['Mediterranean']     4575
# 29449   Brussels  ['Chinese', 'Asian', 'Vegetarian Friendly']     1022
# 43846  Edinburgh                                           []     1488
# 21219     Zurich   ['Italian', 'French', 'Swiss', 'European']     1304
# 42597     Zurich  ['Mexican', 'Latin', 'Vegetarian Friendly']      686
# 2954      London                                ['Fast Food']    15164
# 16057     Munich   ['German', 'European', 'Central European']       43
# 39712       Lyon                                   ['French']     2242
# 34885  Barcelona                                           []     3875
#
#       price_range  reviews_amount  \
# 49123    no price             0.0
# 21164    no price             3.0
# 29449         low            98.0
# 43846    no price             4.0
# 21219      medium             0.0
# 42597      medium            92.0
# 2954          low             6.0
# 16057      medium           319.0
# 39712    no price            11.0
# 34885    no price             3.0
#
#                                                  reviews  \
# 49123                                           [[], []]
# 21164                                           [[], []]
# 29449  [['Fried pork before concert at AB', 'Nice and...
# 43846  [['Pleasant end to a great weekend', 'Excellen...
# 21219                                           [[], []]
# 42597  [['Mexican Food Since Forever', 'maybe the ONL...
# 2954   [['Terrible service', 'normal subway'], ['03/0...
# 16057  [['Bavarian type', 'Fabulous German food'], ['...
# 39712                                           [[], []]
# 34885                                           [[], []]
#
#                                                   url_ta      id_ta  sample  \
# 49123  /Restaurant_Review-g187147-d5957522-Reviews-Da...   d5957522       1
# 21164  /Restaurant_Review-g187849-d7735259-Reviews-Sa...   d7735259       1
# 29449  /Restaurant_Review-g188644-d1065582-Reviews-Ch...   d1065582       1
# 43846  /Restaurant_Review-g186525-d12980019-Reviews-T...  d12980019       1
# 21219  /Restaurant_Review-g188113-d12320624-Reviews-F...  d12320624       1
# 42597  /Restaurant_Review-g188113-d1125309-Reviews-Tr...   d1125309       1
# 2954   /Restaurant_Review-g186338-d3981069-Reviews-Su...   d3981069       0
# 16057  /Restaurant_Review-g187309-d964614-Reviews-Zum...    d964614       1
# 39712  /Restaurant_Review-g187265-d7965591-Reviews-Br...   d7965591       1
# 34885  /Restaurant_Review-g187497-d12556595-Reviews-B...  d12556595       1
#
#        rating latest_review_1 latest_review_2
# 49123     4.0      2017-06-11      2017-04-30
# 21164     4.0      2018-01-06      2017-10-30
# 29449     3.5      2017-07-15      2017-06-12
# 43846     3.5             NaT             NaT
# 21219     4.0      2014-08-14      2014-06-11
# 42597     4.0      2017-04-14      2016-01-20
# 2954      0.0      2017-03-01      2016-11-17
# 16057     4.5      2017-11-15      2017-07-23
# 39712     3.0      2017-10-03      2017-04-01
# 34885     4.5      2017-06-01      2017-03-04

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   city             50000 non-null  object
#  1   cuisine          50000 non-null  object
#  2   ranking          50000 non-null  int64
#  3   price_range      50000 non-null  object
#  4   reviews_amount   50000 non-null  float64
#  5   reviews          49998 non-null  object
#  6   url_ta           50000 non-null  object
#  7   id_ta            50000 non-null  object
#  8   sample           50000 non-null  int64
#  9   rating           50000 non-null  float64
#  10  latest_review_1  41886 non-null  datetime64[ns]
#  11  latest_review_2  36206 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(2), int64(2), object(6)
# memory usage: 4.6+ MB

# %%
print(f'Maximal difference between two latest review dates: {(df.latest_review_1 - df.latest_review_2).max()}')
# Out:
# Maximal difference between two latest review dates: 3296 days 00:00:00

# %%
print(f'The latest review left on: {df.latest_review_1.max()}')
# Out:
# The latest review left on: 2018-02-26 00:00:00

# %% [markdown]
# Let's create a new feature that will probably help us to understand the data better: **difference between the last two review dates**:

# %%
df['review_dates_diff'] = df['latest_review_1'] - df['latest_review_2']
df.drop(['latest_review_1', 'latest_review_2'], axis=1, inplace=True)
df.sample(5)
# Out:
#            city                                            cuisine  ranking  \
# 32220    Berlin                                         ['German']     5279
# 10864    London  ['International', 'Mediterranean', 'Spanish', ...     4355
# 14962  Budapest                                                 []     2345
# 36776    Madrid  ['Bar', 'Cafe', 'Mediterranean', 'European', '...     7766
# 32711    London  ['Spanish', 'Fusion', 'Gluten Free Options', '...     1842
#
#       price_range  reviews_amount  \
# 32220      medium            17.0
# 10864      medium           120.0
# 14962    no price             5.0
# 36776      medium           305.0
# 32711      medium           166.0
#
#                                                  reviews  \
# 32220  [['Fresh food near to Motel One Berlin Bellvu....
# 10864  [['Outstanding', 'My favourite restaurant'], [...
# 14962  [['fraudulent', '" Service was good "'], ['08/...
# 36776  [['Great Patio on the Plaza Mayor', 'Nice plac...
# 32711  [['Again but...', 'High quality food and great...
#
#                                                   url_ta     id_ta  sample  \
# 32220  /Restaurant_Review-g187323-d6642608-Reviews-Ca...  d6642608       1
# 10864  /Restaurant_Review-g186338-d4324139-Reviews-Th...  d4324139       1
# 14962  /Restaurant_Review-g274887-d4077959-Reviews-Re...  d4077959       1
# 36776  /Restaurant_Review-g187514-d1769097-Reviews-Ca...  d1769097       1
# 32711  /Restaurant_Review-g186338-d8422627-Reviews-La...  d8422627       1
#
#        rating review_dates_diff
# 32220     3.5          143 days
# 10864     4.5            1 days
# 14962     2.5          210 days
# 36776     3.0           15 days
# 32711     4.5           58 days

# %% [markdown]
# There are some restaurants which have only one date, that is why the column with date differences can contain negative values. Let's get rid of them:

# %%
df.review_dates_diff = df.review_dates_diff.dropna().dt.days.astype(int).apply(lambda x: 0 if x < 0 else int(x))

# %%
df.head(2)
# Out:
#        city                                            cuisine  ranking  \
# 0     Paris                                     ['Bar', 'Pub']    12963
# 1  Helsinki  ['European', 'Scandinavian', 'Gluten Free Opti...      106
#
#   price_range  reviews_amount  \
# 0      medium             4.0
# 1      medium            97.0
#
#                                              reviews  \
# 0                                           [[], []]
# 1  [['Very good reviews!', 'Fine dining in Hakani...
#
#                                               url_ta      id_ta  sample  \
# 0  /Restaurant_Review-g187147-d10746918-Reviews-L...  d10746918       0
# 1  /Restaurant_Review-g189934-d6674944-Reviews-Ra...   d6674944       0
#
#    rating  review_dates_diff
# 0     0.0                NaN
# 1     0.0               37.0

# %% [markdown]
# Now let's take a look at the distribution of this variable:

# %%
dist_box(df.review_dates_diff)

# %% [markdown]
# Values more than 1000 seem to be quite unrealistic.

# %%
print(f'Amount of values more than 1000: {df[df.review_dates_diff > 1000].review_dates_diff.count()}')
# Out:
# Amount of values more than 1000: 486

# %% [markdown]
# Since 382 values is a small part of the whole dataset, it is possible to delete these values considering them as outliers:

# %%
df.review_dates_diff = df.review_dates_diff.apply(lambda x: np.nan if x > 1000 else x)

# %% [markdown]
# Since there are no reviews (and dates), it is probably sensible to fill missing date differences with zero:

# %%
df.review_dates_diff.fillna(value=0, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   city               50000 non-null  object
#  1   cuisine            50000 non-null  object
#  2   ranking            50000 non-null  int64
#  3   price_range        50000 non-null  object
#  4   reviews_amount     50000 non-null  float64
#  5   reviews            49998 non-null  object
#  6   url_ta             50000 non-null  object
#  7   id_ta              50000 non-null  object
#  8   sample             50000 non-null  int64
#  9   rating             50000 non-null  float64
#  10  review_dates_diff  50000 non-null  float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 4.2+ MB

# %% [markdown]
# ## URL on TripAdvisor

# %%
show_unique('url_ta')
# Out:
# Number of unique values for 'url_ta' column: 49963
#
# Unique values in 'url_ta' column:
#  ['/Restaurant_Review-g187147-d10746918-Reviews-Le_Perchoir-Paris_Ile_de_France.html'
#  '/Restaurant_Review-g189934-d6674944-Reviews-Ravintola_Kolmon3n-Helsinki_Uusimaa.html'
#  '/Restaurant_Review-g186525-d13129638-Reviews-Black_Ivy-Edinburgh_Scotland.html'
#  ...
#  '/Restaurant_Review-g189852-d947615-Reviews-Sushi_Bar_Anu-Stockholm.html'
#  '/Restaurant_Review-g274856-d1100838-Reviews-Honoratka_dawna_Oberza_na_Miodowej-Warsaw_Mazovia_Province_Central_Poland.html'
#  '/Restaurant_Review-g187849-d1109020-Reviews-Taberna_Vasca-Milan_Lombardy.html']

# %%
missing('url_ta')
# Out:
# Number of missing values for column 'url_ta': 0

# %% [markdown]
# **No ideas how to use this information yet, so I will proceed to the next step for now.**

# %%
# lst = []
# for url in urls[:100]:
#     url = 'https://www.tripadvisor.com' + url
#     page = requests.get(url)
#     html = BS(page.content, 'html.parser').text
#     lst.append(re.search(ptrn, html).group(0))
# lst

# %%
df.drop(['url_ta'], axis=1, inplace=True)

# %% [markdown]
# ## ID number on TripAdvisor
#
# This feature gives no additional information for the future model now, so deleting this one makes sense:

# %%
df.drop(['id_ta'], axis=1, inplace=True)

# %% [markdown]
# # Feature Engineering
#
# There is already one new feature which shows how many days passed between two latest reviews on restaurant's web-page.
#
# Now it makes sense go deeper and dig the data for some new features.

# %%
df.sample(5)
# Out:
#          city                                            cuisine  ranking  \
# 40089  Prague                             ['Pizza', 'Fast Food']     2376
# 42562  Madrid  ['Mediterranean', 'European', 'Spanish', 'Wine...      354
# 19504  Berlin  ['Indian', 'Asian', 'Vegetarian Friendly', 'Ve...     1318
# 34503  Madrid                                        ['Spanish']     6165
# 5289   Berlin                                                 []     3347
#
#       price_range  reviews_amount  \
# 40089      medium             7.0
# 42562      medium           313.0
# 19504      medium            49.0
# 34503      medium            30.0
# 5289     no price             0.0
#
#                                                  reviews  sample  rating  \
# 40089  [['Pizza and cafe palace', 'Oh Sweet Lord'], [...       1     4.5
# 42562  [['Good food and quite atmospheric', 'Great Ja...       1     4.5
# 19504  [['Tandoori Food', 'Do they actually have a ta...       1     4.5
# 34503  [['Authentic Spanish meal', 'Not worth the mon...       1     3.5
# 5289                                            [[], []]       0     0.0
#
#        review_dates_diff
# 40089                0.0
# 42562              175.0
# 19504              657.0
# 34503                1.0
# 5289                 0.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   city               50000 non-null  object
#  1   cuisine            50000 non-null  object
#  2   ranking            50000 non-null  int64
#  3   price_range        50000 non-null  object
#  4   reviews_amount     50000 non-null  float64
#  5   reviews            49998 non-null  object
#  6   sample             50000 non-null  int64
#  7   rating             50000 non-null  float64
#  8   review_dates_diff  50000 non-null  float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 3.4+ MB

# %% [markdown]
# ## Length of last two reviews

# %% [markdown]
# Let's try to add a new feature: **mean amount of words in the last two reviews**. Probably if reviews are fake, they will contain less words.
#
# First of all, let's get rid of dates from review column values:

# %%
def delete_dates(x):
    ptrn = r'\d{2}/\d{2}/\d{4}'
    x = re.sub(ptrn, '', x)
    
    return x

# %%
df.reviews = df.reviews.dropna().apply(delete_dates)
df.head()
# Out:
#          city                                            cuisine  ranking  \
# 0       Paris                                     ['Bar', 'Pub']    12963
# 1    Helsinki  ['European', 'Scandinavian', 'Gluten Free Opti...      106
# 2   Edinburgh                            ['Vegetarian Friendly']      810
# 3      London  ['Italian', 'Mediterranean', 'European', 'Vege...     1669
# 4  Bratislava  ['Italian', 'Mediterranean', 'European', 'Seaf...       37
#
#   price_range  reviews_amount  \
# 0      medium             4.0
# 1      medium            97.0
# 2      medium            28.0
# 3        high           202.0
# 4        high           162.0
#
#                                              reviews  sample  rating  \
# 0                                           [[], []]       0     0.0
# 1  [['Very good reviews!', 'Fine dining in Hakani...       0     0.0
# 2  [['Better than the Links', 'Ivy Black'], ['', ...       0     0.0
# 3  [['Most exquisite', 'Delicious and authentic']...       0     0.0
# 4  [['Always the best in bratislava', 'Very good ...       0     0.0
#
#    review_dates_diff
# 0                0.0
# 1               37.0
# 2               22.0
# 3               14.0
# 4               15.0

# %% [markdown]
# Elements in columns **'cuisine'** and **'reviews'** are actually lists but, formally, they are strings.
#
# So, let's format them in order to work with real lists:

# %%
df.cuisine = df.cuisine.str.replace(pat=r"\[|\]|'", repl='', regex=True)
df.cuisine = df.cuisine.str.split(', ')

df.reviews = df.reviews.dropna().str.replace(pat=r",|\[|\]|'", repl='', regex=True)
df.reviews = df.reviews.dropna().str.split()

print(type(df.cuisine.iloc[0]) is list)
print(type(df.reviews.iloc[0]) is list)
# Out:
# True
# True

# %%
df.head()
# Out:
#          city                                            cuisine  ranking  \
# 0       Paris                                         [Bar, Pub]    12963
# 1    Helsinki  [European, Scandinavian, Gluten Free Options, ...      106
# 2   Edinburgh                              [Vegetarian Friendly]      810
# 3      London  [Italian, Mediterranean, European, Vegetarian ...     1669
# 4  Bratislava  [Italian, Mediterranean, European, Seafood, Ve...       37
#
#   price_range  reviews_amount  \
# 0      medium             4.0
# 1      medium            97.0
# 2      medium            28.0
# 3        high           202.0
# 4        high           162.0
#
#                                              reviews  sample  rating  \
# 0                                                 []       0     0.0
# 1  [Very, good, reviews!, Fine, dining, in, Hakan...       0     0.0
# 2             [Better, than, the, Links, Ivy, Black]       0     0.0
# 3       [Most, exquisite, Delicious, and, authentic]       0     0.0
# 4  [Always, the, best, in, bratislava, Very, good...       0     0.0
#
#    review_dates_diff
# 0                0.0
# 1               37.0
# 2               22.0
# 3               14.0
# 4               15.0

# %%
df['reviews'].fillna(value='', inplace=True)

# %%
df['review_length'] = df['reviews'].apply(lambda x: len(x))
df.sample(2)
# Out:
#          city           cuisine  ranking price_range  reviews_amount  \
# 49235  Vienna  [Chinese, Sushi]     2347         low             5.0
# 8622   Munich            [Cafe]      799      medium            38.0
#
#                                                  reviews  sample  rating  \
# 49235  [Good, local, and, good, food, for, reasonable...       1     4.0
# 8622   [Nice, coffee, good, cocktails, Great, coffee,...       0     0.0
#
#        review_dates_diff  review_length
# 49235                0.0              8
# 8622               506.0              8

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   city               50000 non-null  object
#  1   cuisine            50000 non-null  object
#  2   ranking            50000 non-null  int64
#  3   price_range        50000 non-null  object
#  4   reviews_amount     50000 non-null  float64
#  5   reviews            50000 non-null  object
#  6   sample             50000 non-null  int64
#  7   rating             50000 non-null  float64
#  8   review_dates_diff  50000 non-null  float64
#  9   review_length      50000 non-null  int64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 3.8+ MB

# %% [markdown]
# ## Number of cuisines a restaurant has
#
# > There is an assumption that the more cuisines the restaurant has, the worse its dishes (and therefore the rating) are because there is not just one cuisine which the restaurant specializes in. It is probably more difficult to be good at cooking all the dishes from different cuisines rather than being excellent in one cuisine.
#
# The idea is to count **how many different cuisines a restaurant has** and put this values into a new vector-column.

# %%
df['cuisines_amount'] = df['cuisine'].apply(lambda x: len(x))
df.head(2)
# Out:
#        city                                            cuisine  ranking  \
# 0     Paris                                         [Bar, Pub]    12963
# 1  Helsinki  [European, Scandinavian, Gluten Free Options, ...      106
#
#   price_range  reviews_amount  \
# 0      medium             4.0
# 1      medium            97.0
#
#                                              reviews  sample  rating  \
# 0                                                 []       0     0.0
# 1  [Very, good, reviews!, Fine, dining, in, Hakan...       0     0.0
#
#    review_dates_diff  review_length  cuisines_amount
# 0                0.0              0                2
# 1               37.0              7                5

# %%
df.corr()
# Out:
#                     ranking  reviews_amount    sample    rating  \
# ranking            1.000000       -0.223198  0.006271 -0.109897
# reviews_amount    -0.223198        1.000000  0.002688  0.011006
# sample             0.006271        0.002688  1.000000  0.936543
# rating            -0.109897        0.011006  0.936543  1.000000
# review_dates_diff  0.008152       -0.010760 -0.004101 -0.004340
# review_length     -0.109698        0.152823  0.003065  0.007229
# cuisines_amount   -0.322408        0.409446 -0.003202  0.034506
#
#                    review_dates_diff  review_length  cuisines_amount
# ranking                     0.008152      -0.109698        -0.322408
# reviews_amount             -0.010760       0.152823         0.409446
# sample                     -0.004101       0.003065        -0.003202
# rating                     -0.004340       0.007229         0.034506
# review_dates_diff           1.000000       0.053654        -0.024266
# review_length               0.053654       1.000000         0.266104
# cuisines_amount            -0.024266       0.266104         1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50000 entries, 0 to 49999
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   city                  50000 non-null  object
#  1   cuisine               50000 non-null  object
#  2   ranking               50000 non-null  int64
#  3   reviews_amount        50000 non-null  float64
#  4   reviews               50000 non-null  object
#  5   sample                50000 non-null  int64
#  6   rating                50000 non-null  float64
#  7   review_dates_diff     50000 non-null  float64
#  8   review_length         50000 non-null  int64
#  9   cuisines_amount       50000 non-null  int64
#  10  tourists              50000 non-null  int64
#  11  city_rank             48804 non-null  float64
#  12  price_range_high      50000 non-null  uint8
#  13  price_range_low       50000 non-null  uint8
#  14  price_range_medium    50000 non-null  uint8
#  15  price_range_no price  50000 non-null  uint8
#  16  id_ta                 50000 non-null  object
#  17  rest_id               50000 non-null  object
#  18  chain                 50000 non-null  int64
#  19  dummy_veg             50000 non-null  int64
#  20  pop_city              50000 non-null  int64
# dtypes: float64(4), int64(8), object(5), uint8(4)
# memory usage: 7.1+ MB

# %% [markdown]
# ## Annual number of tourists for each city
#
# Let's try to add some information about tourist flow from [Wikipedia](https://en.wikipedia.org/wiki/List_of_cities_by_international_visitors) and Google.
#
# I created a file containing information from Wikipedia about most of the cities we have in our dataset. Nevertheless, some of the cities are absent, so it is necessary to use google for additional info.

# %%
cities = df.city.unique()

# %%
tourists_by_city = {}

# %%
tourism = pd.read_csv('../input/tourism/tourism.txt', sep='\t', header=None, usecols=[2, 4, 5])  
tourism.columns=['city', '2018', '2016']
tourism.city = tourism.city.str.strip().replace({'Porto': 'Oporto', 'Kraków': 'Krakow'})
tourism = tourism.set_index('city')

# %%
for city in cities:
    if city in tourism.index:
        if not pd.isna(tourism.loc[city]['2018']):
            tourists_by_city[city] = int(tourism.loc[city]['2018'].replace(',', ''))
        elif not pd.isna(tourism.loc[city]['2016']):
            tourists_by_city[city] = int(tourism.loc[city]['2016'].replace(',', ''))
    else:
        tourists_by_city[city] = 0

# %% [markdown]
# The dictionary is almost complete:

# %%
tourists_by_city
# Out:
# {'Paris': 17560200,
#  'Helsinki': 0,
#  'Edinburgh': 0,
#  'London': 19233000,
#  'Bratislava': 0,
#  'Lisbon': 3539400,
#  'Budapest': 3822800,
#  'Stockholm': 2604600,
#  'Rome': 10065400,
#  'Milan': 6481300,
#  'Munich': 4066600,
#  'Hamburg': 0,
#  'Prague': 8948600,
#  'Vienna': 6410300,
#  'Dublin': 5213400,
#  'Barcelona': 6714500,
#  'Brussels': 3942000,
#  'Madrid': 5440100,
#  'Oslo': 0,
#  'Amsterdam': 8354200,
#  'Berlin': 5959400,
#  'Lyon': 0,
#  'Athens': 5728400,
#  'Warsaw': 2850000,
#  'Oporto': 2341300,
#  'Krakow': 2732000,
#  'Copenhagen': 3069700,
#  'Luxembourg': 0,
#  'Zurich': 0,
#  'Geneva': 0,
#  'Ljubljana': 0}

# %% [markdown]
# Filling missed cities:

# %%
tourists_by_city['Bratislava'] = 125500
tourists_by_city['Hamburg'] = 1450000
tourists_by_city['Zurich'] = 2240000
tourists_by_city['Lyon'] = 6000000
tourists_by_city['Oslo'] = 4800000
tourists_by_city['Helsinki'] = 4000000
tourists_by_city['Edinburgh'] = 2015000
tourists_by_city['Geneva'] = 1050000
tourists_by_city['Ljubljana'] = 6200000
tourists_by_city['Luxembourg'] = 1139

# %% [markdown]
# So now there is a full dictionary with city-tourists pairs and it is time to add this info to TA Dataset:

# %%
def tourists_amount(row):
    row['tourists'] = tourists_by_city[row['city']]
    
    return row

# %%
df.city.unique()
# Out:
# array(['Paris', 'Helsinki', 'Edinburgh', 'London', 'Bratislava', 'Lisbon',
#        'Budapest', 'Stockholm', 'Rome', 'Milan', 'Munich', 'Hamburg',
#        'Prague', 'Vienna', 'Dublin', 'Barcelona', 'Brussels', 'Madrid',
#        'Oslo', 'Amsterdam', 'Berlin', 'Lyon', 'Athens', 'Warsaw',
#        'Oporto', 'Krakow', 'Copenhagen', 'Luxembourg', 'Zurich', 'Geneva',
#        'Ljubljana'], dtype=object)

# %%
df['tourists'] = pd.Series(np.array([0 for i in range(len(df))]))
df = df.apply(tourists_amount, axis=1)

# %%
df.sample(2)
# Out:
#          city cuisine  ranking price_range  reviews_amount  \
# 34694  Madrid      []     8083    no price             3.0
# 7337   Warsaw      []     2013    no price             5.0
#
#                                      reviews  sample  rating  \
# 34694                                     []       1     3.0
# 7337   [not, worth, the, prize, Great, food]       0     0.0
#
#        review_dates_diff  review_length  cuisines_amount  tourists
# 34694                5.0              0                1   5440100
# 7337                30.0              6                1   2850000

# %%
fig = plt.figure(figsize=(14, 6))
sns.heatmap(df.corr(), annot=True)

# %% [markdown]
# ## Living standards ranking
#
# Another variable I would like to add to the dataframe is the **quality of living ranking** which is provided by a famous consulting company [Mercer](https://mobilityexchange.mercer.com/Insights/quality-of-living-rankings).
#
# The first step is to create a CSV file with that table from Mercer's report:

# %%
ls = pd.read_csv('../input/living-standards/living_standards.txt', sep='\t')
ls
# Out:
#      Rank            City            Country/region
# 0       1          Vienna                   Austria
# 1       2          Zurich               Switzerland
# 2       3       Vancouver                    Canada
# 3       3          Munich                   Germany
# 4       3        Auckland               New Zealand
# ..    ...             ...                       ...
# 226   227        Khartoum                     Sudan
# 227   228  Port au Prince                     Haiti
# 228   229          Sana'a       Yemen Arab Republic
# 229   230          Bangui  Central African Republic
# 230   231         Baghdad                      Iraq
#
# [231 rows x 3 columns]

# %% [markdown]
# The second step is to extract only necessary cities:

# %%
ls = ls[ls['City'].isin(list(df.city.unique()))][['Rank', 'City']]
ls.columns = ['city_rank', 'city']
print(ls.shape)
display(ls.head(5))
# Out:
# (29, 2)
#    city_rank        city
# 0          1      Vienna
# 1          2      Zurich
# 3          3      Munich
# 7          8  Copenhagen
# 8          9      Geneva

# %%
ls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29 entries, 0 to 88
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   city_rank  29 non-null     int64
#  1   city       29 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 696.0+ bytes

# %% [markdown]
# Since ctities' ranks are objects, it is important to format them to int type:

# %%
ls.city_rank = ls.city_rank.astype(int)

# %%
ls.city.unique()
# Out:
# array(['Vienna', 'Zurich', 'Munich', 'Copenhagen', 'Geneva', 'Amsterdam',
#        'Berlin', 'Luxembourg', 'Hamburg', 'Stockholm', 'Oslo', 'Brussels',
#        'Helsinki', 'Dublin', 'Lisbon', 'Paris', 'Lyon', 'Milan', 'London',
#        'Barcelona', 'Edinburgh', 'Madrid', 'Rome', 'Prague', 'Ljubljana',
#        'Budapest', 'Bratislava', 'Warsaw', 'Athens'], dtype=object)

# %% [markdown]
# Obviously, there are only 2 cities which were not included in this report:

# %%
set(df.city.unique()).difference(set(ls.city.unique()))
# Out:
# {'Krakow', 'Oporto'}

# %%
number = len(df[df.city.isin(['Krakow', 'Oporto'])])
print(f'Number of restaurants from Krakow and Oporto: {number}')
# Out:
# Number of restaurants from Krakow and Oporto: 1196

# %% [markdown]
# Let's try to merge living standards with initial dataframe:

# %%
df = df.merge(ls, how='left', on='city')
df.shape
# Out:
# (50000, 13)

# %%
df.head(2)
# Out:
#        city                                            cuisine  ranking  \
# 0     Paris                                         [Bar, Pub]    12963
# 1  Helsinki  [European, Scandinavian, Gluten Free Options, ...      106
#
#   price_range  reviews_amount  \
# 0      medium             4.0
# 1      medium            97.0
#
#                                              reviews  sample  rating  \
# 0                                                 []       0     0.0
# 1  [Very, good, reviews!, Fine, dining, in, Hakan...       0     0.0
#
#    review_dates_diff  review_length  cuisines_amount  tourists  city_rank
# 0                0.0              0                2  17560200       39.0
# 1               37.0              7                5   4000000       31.0

# %%
df.corr()
# Out:
#                     ranking  reviews_amount    sample    rating  \
# ranking            1.000000       -0.223198  0.006271 -0.109897
# reviews_amount    -0.223198        1.000000  0.002688  0.011006
# sample             0.006271        0.002688  1.000000  0.936543
# rating            -0.109897        0.011006  0.936543  1.000000
# review_dates_diff  0.008152       -0.010760 -0.004101 -0.004340
# review_length     -0.109698        0.152823  0.003065  0.007229
# cuisines_amount   -0.322408        0.409446 -0.003202  0.034506
# tourists           0.658372        0.044322  0.002046 -0.005728
# city_rank          0.077766        0.063760  0.003006  0.005079
#
#                    review_dates_diff  review_length  cuisines_amount  \
# ranking                     0.008152      -0.109698        -0.322408
# reviews_amount             -0.010760       0.152823         0.409446
# sample                     -0.004101       0.003065        -0.003202
# rating                     -0.004340       0.007229         0.034506
# review_dates_diff           1.000000       0.053654        -0.024266
# review_length               0.053654       1.000000         0.266104
# cuisines_amount            -0.024266       0.266104         1.000000
# tourists                   -0.003109       0.086969         0.012619
# city_rank                  -0.006364      -0.028453         0.030761
#
#                    tourists  city_rank
# ranking            0.658372   0.077766
# reviews_amount     0.044322   0.063760
# sample             0.002046   0.003006
# rating            -0.005728   0.005079
# review_dates_diff -0.003109  -0.006364
# review_length      0.086969  -0.028453
# cuisines_amount    0.012619   0.030761
# tourists           1.000000   0.142025
# city_rank          0.142025   1.000000

# %% [markdown]
# The correlation between **review dates difference, review_length, tourists, city_rank** and **rating** is weak. It is probably better to drop it.

# %%
# new_df = df.drop(['review_dates_diff', 'tourists', 'city_rank', 'review_length'], axis=1)

# %%
new_df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-137-b883df5fcbe1> in <module>
# ----> 1 new_df.info()
#
# NameError: name 'new_df' is not defined

# %% [markdown]
# ## Dummy price range

# %%
new_df.head(1)

# %% [markdown]
# Now, let's see if there are significant differences between the ratings of restaurants depending on their price range or city.
#
# For this purposes Student's t-test can be used since the data in **'rating'** column is normally distributed.

# %%
for column in ['city', 'price_range']:
    combs =  combinations(list(df[column].dropna().unique()), 2)
    for comb in combs:
        p_value = stats.ttest_ind(df[df[column] == comb[0]].rating.dropna(),
                                  df[df[column] == comb[1]].rating.dropna()).pvalue
        if (p_value / len(list(combs))) < 0.05:
            print(f'Statistically significant differences found for column \"{column}\"')
            break
# Out:
# Statistically significant differences found for column "city"
# Statistically significant differences found for column "price_range"

# %% [markdown]
# **Getting dummies for price range:**

# %%
df = pd.get_dummies(df, columns=['price_range'])

# %% [markdown]
# ## Dummy vegan cuisine
#
# Since vegetarian cuisine is the most frequent, let's try to make a dummy variable where:
# * **1** - it is a vegetarian cuisine,
# * **0** - it is not

# %%
dummy_veg = pd.DataFrame(df.cuisine.astype(str).str.contains('Veg').astype(int))
df['dummy_veg'] = dummy_veg

# %%
df.head(1)
# Out:
#     city     cuisine  ranking  reviews_amount reviews  sample  rating  \
# 0  Paris  [Bar, Pub]    12963             4.0      []       0     0.0
#
#    review_dates_diff  review_length  cuisines_amount  tourists  city_rank  \
# 0                0.0              0                2  17560200       39.0
#
#    price_range_high  price_range_low  price_range_medium  \
# 0                 0                0                   1
#
#    price_range_no price      id_ta rest_id  chain  dummy_veg
# 0                     0  d10746918    id_0      1          0

# %% [markdown]
# ## Dummy most frequent cities
#
# Probably, reference to a popular city will help to define our target variable:

# %%
df['pop_city'] = df.city.astype(str).str.contains(r'London|Paris', regex=True).astype(int)
df.sample(4)
# Out:
#             city   cuisine  ranking  reviews_amount  \
# 33277     Berlin        []     5102             0.0
# 44373     Berlin  [German]     3887            22.0
# 34604  Barcelona        []     2847            18.0
# 28609      Paris        []     9502             3.0
#
#                                                  reviews  sample  rating  \
# 33277                                                 []       1     4.0
# 44373  [Nie, wieder, Awful, service, poor, food, sele...       1     4.0
# 34604                                                 []       1     4.5
# 28609         [Excellent, Lunch, Spot, for, To-Go, Food]       1     4.5
#
#        review_dates_diff  review_length  cuisines_amount  ...  city_rank  \
# 33277               47.0              0                1  ...       13.0
# 44373                0.0              8                1  ...       13.0
# 34604               45.0              0                1  ...       43.0
# 28609                0.0              6                1  ...       39.0
#
#        price_range_high  price_range_low  price_range_medium  \
# 33277                 0                0                   0
# 44373                 0                0                   1
# 34604                 0                0                   0
# 28609                 0                0                   0
#
#        price_range_no price      id_ta  rest_id chain  dummy_veg  pop_city
# 33277                     1   d5519956  id_5100     0          0         0
# 44373                     0   d7251676  id_3885     0          0         0
# 34604                     1   d9751117  id_2846     1          0         0
# 28609                     1  d11805408  id_9500     0          0         1
#
# [4 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50000 entries, 0 to 49999
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   city                  50000 non-null  object
#  1   cuisine               50000 non-null  object
#  2   ranking               50000 non-null  int64
#  3   reviews_amount        50000 non-null  float64
#  4   reviews               50000 non-null  object
#  5   sample                50000 non-null  int64
#  6   rating                50000 non-null  float64
#  7   review_dates_diff     50000 non-null  float64
#  8   review_length         50000 non-null  int64
#  9   cuisines_amount       50000 non-null  int64
#  10  tourists              50000 non-null  int64
#  11  city_rank             48804 non-null  float64
#  12  price_range_high      50000 non-null  uint8
#  13  price_range_low       50000 non-null  uint8
#  14  price_range_medium    50000 non-null  uint8
#  15  price_range_no price  50000 non-null  uint8
#  16  id_ta                 50000 non-null  object
#  17  rest_id               50000 non-null  object
#  18  chain                 50000 non-null  int64
#  19  dummy_veg             50000 non-null  int64
#  20  pop_city              50000 non-null  int64
# dtypes: float64(4), int64(8), object(5), uint8(4)
# memory usage: 7.1+ MB

# %% [markdown]
# ## Dummy chain restaurant
#
# Probably, the rating also depends on whether it is a chain of restaurants or not.
#
# I will consider a restaurant as a chain one if it occurs more than 5 times in dataset.

# %%
df['id_ta'] = data['ID_TA']
df['rest_id'] = data['Restaurant_id']

# %%
df['chain'] = df.rest_id.map(dict((df.rest_id.value_counts() > 5).astype(int)))
df.head(5)
# Out:
#          city                                            cuisine  ranking  \
# 0       Paris                                         [Bar, Pub]    12963
# 1    Helsinki  [European, Scandinavian, Gluten Free Options, ...      106
# 2   Edinburgh                              [Vegetarian Friendly]      810
# 3      London  [Italian, Mediterranean, European, Vegetarian ...     1669
# 4  Bratislava  [Italian, Mediterranean, European, Seafood, Ve...       37
#
#    reviews_amount                                            reviews  sample  \
# 0             4.0                                                 []       0
# 1            97.0  [Very, good, reviews!, Fine, dining, in, Hakan...       0
# 2            28.0             [Better, than, the, Links, Ivy, Black]       0
# 3           202.0       [Most, exquisite, Delicious, and, authentic]       0
# 4           162.0  [Always, the, best, in, bratislava, Very, good...       0
#
#    rating  review_dates_diff  review_length  cuisines_amount  ...  city_rank  \
# 0     0.0                0.0              0                2  ...       39.0
# 1     0.0               37.0              7                5  ...       31.0
# 2     0.0               22.0              6                1  ...       45.0
# 3     0.0               14.0              5                5  ...       41.0
# 4     0.0               15.0              9                6  ...       80.0
#
#    price_range_high  price_range_low  price_range_medium  \
# 0                 0                0                   1
# 1                 0                0                   1
# 2                 0                0                   1
# 3                 1                0                   0
# 4                 1                0                   0
#
#    price_range_no price      id_ta rest_id chain  dummy_veg  pop_city
# 0                     0  d10746918    id_0     1          0         1
# 1                     0   d6674944    id_1     1          1         0
# 2                     0  d13129638    id_2     1          1         0
# 3                     0    d680417    id_3     1          1         1
# 4                     0   d1112354    id_4     1          1         0
#
# [5 rows x 21 columns]

# %% [markdown]
# Finally, a correlation matrix will show approximately which features are significant:

# %%
fig = plt.figure(figsize=(14, 6))
sns.heatmap(df.drop(['sample', 'chain', 'dummy_veg', 'pop_city'], axis=1).corr(), annot=True)

# %% [markdown]
# * Review dates difference only makes the model work worse
#
# *

# %% [markdown]
# # Data preprocessing - function
#
# Creating a function which contains all the steps of preprocessing for better reproducibility and convenience

# %%
df_train = pd.read_csv(DATA_DIR+'/main_task.csv')
df_test = pd.read_csv(DATA_DIR+'/kaggle_task.csv')
df_train['sample'] = 1
df_test['sample'] = 0 
df_test['Rating'] = 0 

data = df_test.append(df_train, sort=False).reset_index(drop=True) # объединяем
data.info()

cities = data.City.unique()
tourists_by_city = {}
tourism = pd.read_csv('../input/tourism/tourism.txt', sep='\t', header=None, usecols=[2, 4, 5])  
tourism.columns=['city', '2018', '2016']
tourism.city = tourism.city.str.strip().replace({'Porto': 'Oporto', 'Kraków': 'Krakow'})
tourism = tourism.set_index('city')

for city in cities:
    if city in tourism.index:
        if not pd.isna(tourism.loc[city]['2018']):
            tourists_by_city[city] = int(tourism.loc[city]['2018'].replace(',', ''))
        elif not pd.isna(tourism.loc[city]['2016']):
            tourists_by_city[city] = int(tourism.loc[city]['2016'].replace(',', ''))
    else:
        tourists_by_city[city] = 0  
        
tourists_by_city['Bratislava'] = 125500
tourists_by_city['Hamburg'] = 1450000
tourists_by_city['Zurich'] = 2240000
tourists_by_city['Lyon'] = 6000000
tourists_by_city['Oslo'] = 4800000
tourists_by_city['Helsinki'] = 4000000
tourists_by_city['Edinburgh'] = 2015000
tourists_by_city['Geneva'] = 1050000
tourists_by_city['Ljubljana'] = 6200000
tourists_by_city['Luxembourg'] = 1139

ls = pd.read_csv('../input/living-standards/living_standards.txt', sep='\t')
ls = ls[ls['City'].isin(list(data.City.unique()))][['Rank', 'City']]
ls.columns = ['city_rank', 'city']
ls.city_rank = ls.city_rank.astype(int)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Restaurant_id      50000 non-null  object
#  1   City               50000 non-null  object
#  2   Cuisine Style      38410 non-null  object
#  3   Ranking            50000 non-null  float64
#  4   Price Range        32639 non-null  object
#  5   Number of Reviews  46800 non-null  float64
#  6   Reviews            49998 non-null  object
#  7   URL_TA             50000 non-null  object
#  8   ID_TA              50000 non-null  object
#  9   sample             50000 non-null  int64
#  10  Rating             50000 non-null  float64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 4.2+ MB

# %%
def preproc_data(df_input):
    '''includes several functions to pre-process the predictor data.'''
    
    df_output = df_input.copy()
    
    # ################### 1. Preprocessing ############################################################## 

    df_output.columns = ['rest_id', 'city', 'cuisine', 'ranking',
                'price_range', 'reviews_amount', 'reviews', 'url_ta',
                'id_ta', 'sample', 'rating']
    df_output.drop(['id_ta', 'url_ta'], axis = 1, inplace=True)
    
    
    
    # ################### 2. NAN ############################################################## 
    # Cuisine
    df_output.cuisine.fillna('[]', inplace=True)

    # Amount of reviews
    df_output.reviews_amount.fillna(value=0, inplace=True)
    
    # Rating
#     df_output = df_output[(df_output.rating > 3) | (df_output.rating == 0)]

    
    
    # ################### 3. Encoding ############################################################## 
    # Dummy most popular city
#     df_output['pop_city'] = df_output.city.astype(str).str.contains(r'London|Paris', regex=True).astype(int)
    
    # Dummy City
#     df_output = pd.concat([df_output, pd.get_dummies(df_output.city)], axis=1)
    
    # Dummy Price Range
    df_output.price_range = df_output.price_range.map({'$': 'low', '$$ - $$$': 'medium', '$$$$': 'high', np.nan: 'no price'})
    df_output = pd.get_dummies(df_output, columns=['price_range'])
    
    # Dummy vegan cuisine
#     dummy_veg = pd.DataFrame(df_output.cuisine.astype(str).str.contains('Veg').astype(int))
#     df_output['dummy_veg'] = dummy_veg
    
    # Dummy chain restaurant
#     df_output['chain'] = df_output.rest_id.map(dict((df_output.rest_id.value_counts() > 5).astype(int)))
#     df_output.drop(['rest_id'], axis=1, inplace=True)
    
    # ################### 4. Feature Engineering ####################################################
    # Cuisines amount
    df_output['cuisines_amount'] = df_output['cuisine'].apply(lambda x: len(x))
    
#     Annual number of tourists
    def tourists_amount(row):
        row['tourists'] = tourists_by_city[row['city']]
        return row
    
    
    df_output['tourists'] = pd.Series(np.array([0 for i in range(len(df_output))]))
    df_output = df_output.apply(tourists_amount, axis=1)
    
    # City quality rank
    df_output = df_output.merge(ls, how='left', on='city')
    df_output['city_rank'].fillna(method='bfill', inplace=True)
    
    
    # ################### 5. Clean #################################################### 
    ranking = df_output[['city', 'ranking']]
    object_columns = [s for s in df_output.columns if df_output[s].dtypes == 'object']
    df_output.drop(object_columns, axis = 1, inplace=True)
    
    minmax_scale = MinMaxScaler(feature_range=(0, 1))
    for column in df_output.columns:
        if column not in ['rating', 'ranking']:
            df_output[[column]] = minmax_scale.fit_transform(df_output[[column]])
               
    def scaler(x):
        x_scaled = (x - np.min(x)) / (np.max(x) - np.min(x))
        return x_scaled
    
    df_output['ranking'] = ranking.groupby('city')['ranking'].apply(lambda x: scaler(x))
    
    
    return df_output

# %% [markdown]
# **Since everything is scaled, the model can be built:**

# %%
df_preproc = preproc_data(data).dropna()
df_preproc.sample(10)

train_data = df_preproc.query('sample == 1').drop(['sample'], axis=1)
test_data = df_preproc.query('sample == 0').drop(['sample'], axis=1)

# %%
y = train_data.rating.values
X = train_data.drop(['rating'], axis=1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=RANDOM_SEED)

model = RandomForestRegressor(n_estimators=100, verbose=1, n_jobs=-1, random_state=RANDOM_SEED)


model.fit(X_train, y_train)

y_pred = model.predict(X_test)

print('MAE:', metrics.mean_absolute_error(y_test, y_pred))
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    3.7s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:    0.1s finished
# MAE: 0.20648312499999996

# %%
test_data.shape, train_data.shape, X.shape, X_train.shape, X_test.shape
# Out:
# ((10000, 10), (40000, 10), (40000, 9), (32000, 9), (8000, 9))

# %%
df_preproc.sample(10)
# Out:
#         ranking  reviews_amount  sample  rating  price_range_high  \
# 48840  0.200458        0.013354     1.0     4.0               0.0
# 6454   0.035636        0.009213     0.0     0.0               0.0
# 18659  0.132152        0.003520     1.0     4.5               0.0
# 3456   0.277899        0.005797     0.0     0.0               0.0
# 17960  0.769349        0.008903     1.0     3.5               0.0
# 49639  0.958235        0.002795     1.0     2.5               1.0
# 20418  0.757769        0.003002     1.0     4.0               0.0
# 17832  0.739328        0.000414     1.0     3.5               0.0
# 41094  0.938476        0.000725     1.0     2.5               0.0
# 27753  0.137453        0.021325     1.0     4.0               0.0
#
#        price_range_low  price_range_medium  price_range_no price  \
# 48840              1.0                 0.0                   0.0
# 6454               0.0                 1.0                   0.0
# 18659              0.0                 1.0                   0.0
# 3456               0.0                 1.0                   0.0
# 17960              0.0                 1.0                   0.0
# 49639              0.0                 0.0                   0.0
# 20418              0.0                 1.0                   0.0
# 17832              0.0                 0.0                   1.0
# 41094              0.0                 0.0                   1.0
# 27753              0.0                 1.0                   0.0
#
#        cuisines_amount  tourists  city_rank
# 48840         0.210728  0.913019   0.431818
# 6454          0.256705  0.309812   0.136364
# 18659         0.352490  0.333257   0.000000
# 3456          0.168582  0.211392   0.022727
# 17960         0.068966  0.349075   0.477273
# 49639         0.034483  0.913019   0.431818
# 20418         0.057471  0.333257   0.000000
# 17832         0.000000  0.282810   0.511364
# 41094         0.000000  0.336949   0.454545
# 27753         0.076628  0.913019   0.431818

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40000 entries, 10000 to 49999
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ranking               40000 non-null  float64
#  1   reviews_amount        40000 non-null  float64
#  2   rating                40000 non-null  float64
#  3   price_range_high      40000 non-null  float64
#  4   price_range_low       40000 non-null  float64
#  5   price_range_medium    40000 non-null  float64
#  6   price_range_no price  40000 non-null  float64
#  7   cuisines_amount       40000 non-null  float64
#  8   tourists              40000 non-null  float64
#  9   city_rank             40000 non-null  float64
# dtypes: float64(10)
# memory usage: 3.4 MB

# %% [markdown]
# Displaying the most important variables:

# %%
plt.rcParams['figure.figsize'] = (10,10)
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(15).plot(kind='barh')

# %% [markdown]
# Submission

# %%
test_data.sample(10)
# Out:
#        ranking  reviews_amount  rating  price_range_high  price_range_low  \
# 8041  0.894302        0.000000     0.0               0.0              0.0
# 4881  0.616463        0.001346     0.0               0.0              1.0
# 2432  0.223887        0.012112     0.0               0.0              0.0
# 8157  0.306392        0.003727     0.0               0.0              0.0
# 3997  0.054422        0.095238     0.0               0.0              0.0
# 3499  0.775899        0.001035     0.0               0.0              0.0
# 6411  0.237852        0.010663     0.0               0.0              0.0
# 7430  0.938062        0.000725     0.0               0.0              0.0
# 9551  0.324004        0.001346     0.0               0.0              1.0
# 6067  0.796175        0.000518     0.0               0.0              1.0
#
#       price_range_medium  price_range_no price  cuisines_amount  tourists  \
# 8041                 0.0                   1.0         0.034483  1.000000
# 4881                 0.0                   0.0         0.022989  0.913019
# 2432                 1.0                   0.0         0.344828  0.282810
# 8157                 1.0                   0.0         0.126437  1.000000
# 3997                 1.0                   0.0         0.421456  0.349075
# 3499                 0.0                   1.0         0.000000  0.434335
# 6411                 0.0                   1.0         0.034483  0.282810
# 7430                 0.0                   1.0         0.122605  0.204913
# 9551                 0.0                   0.0         0.091954  0.183979
# 6067                 0.0                   0.0         0.057471  0.349075
#
#       city_rank
# 8041   0.454545
# 4881   0.431818
# 2432   0.511364
# 8157   0.454545
# 3997   0.477273
# 3499   0.113636
# 6411   0.511364
# 7430   0.306818
# 9551   0.409091
# 6067   0.477273

# %%
test_data = test_data.drop(['rating'], axis=1)

# %%
sample_submission.sample(20)
# Out:
#      Restaurant_id  Rating
# 2033       id_2033     1.0
# 1487       id_1487     1.0
# 4818       id_4818     2.0
# 8126       id_8126     3.0
# 675         id_675     5.0
# 9598       id_9598     4.0
# 5166       id_5166     3.0
# 1746       id_1746     2.5
# 404         id_404     4.5
# 3095       id_3095     4.5
# 4956       id_4956     5.0
# 3205       id_3205     3.0
# 9031       id_9031     4.0
# 7839       id_7839     4.0
# 3416       id_3416     4.0
# 9842       id_9842     3.0
# 4018       id_4018     2.0
# 5363       id_5363     2.0
# 4734       id_4734     2.0
# 1894       id_1894     1.0

# %%
predict_submission = model.predict(test_data)
# Out:
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:    0.1s finished

# %%
predict_submission
# Out:
# array([3.015, 4.315, 4.23 , ..., 3.085, 4.46 , 4.18 ])

# %%
sample_submission['Rating'] = predict_submission
sample_submission.to_csv('submission.csv', index=False)
sample_submission.head(10)
# Out:
#   Restaurant_id  Rating
# 0          id_0   3.015
# 1          id_1   4.315
# 2          id_2   4.230
# 3          id_3   4.340
# 4          id_4   4.475
# 5          id_5   4.555
# 6          id_6   1.825
# 7          id_7   2.575
# 8          id_8   4.215
# 9          id_9   4.670
